# %%
#@title Temporary Vps
#@markdown Fill The Forms
import os
import time
tool = "ZxCDDoS" #@param ["ZxCDDoS", "Stanley"]
os.system("apt update")
os.system("apt install golang")
# %cd ~
if tool == "Stanley":
   os.system("rm -rf Stanley")
   os.system("git clone https://github.com/nalayakofficial/Stanley")
   # %cd Stanley
   print("DownLoaded Stanley")
else:
   os.system("rm -rf ZxCDDos")
   os.system("git clone https://github.com/nalayakofficial/ZxCDDoS")
   # %cd ZxCDDoS
   print("DownLoaded ZxDDos")

print("Setting up")
import os
setupTool = "pip"#@param ["pip", "pip3"]
setupType = "fast"#@param ["fast", "full"]
if setupTool == 'pip':
    os.system("pip install speedtest-cli")
    os.system("pip install PySocks")
    os.system("pip install cfscrape")
    os.system("pip install datetime")
    os.system("pip install ssl")
    os.system("pip install threading")
    os.system("pip install imcplib")
    os.system("pip install scapy")
    
elif setupTool == 'pip3':
    os.system("pip3 install speedtest-cli")
    os.system("pip3 install PySocks")
    os.system("pip3 install cfscrape")
    os.system("pip3 install datetime")
    os.system("pip3 install ssl")
    os.system("pip3 install threading")
    os.system("pip3 install imcplib")
    os.system("pip3 install scapy")
else:
    print("huh")
    
print("Python libs Setted up")

if setupType == "full":
    print("Doing Full Setup")
    os.system("sudo apt-get install nodejs -y")
    print("Nodejs Installed")
    os.system("sudo apt-get install npm -y")
    print("NPM Installed")
    os.system("npm i events -y")
    os.system("npm i fs -y")
    os.system("npm i url -y")
    os.system("npm i net -y")
    os.system("npm i cloudscraper -y")
    os.system("npm i request -y")
    os.system("npm i randomstring -y")
    os.system("npm i cluster -y")
    os.system("npm i cloudflare-bypasser -y")
    os.system("npm i hcaptcha-solver -y")

os.system("ulimit -n 999999 -y")
os.system("chmod +x * -y")
print("Setup Done !")
user='root'
password='root'
print("Setting Up Vps")
! pip install colab_ssh --upgrade &> /dev/null
from colab_ssh import launch_ssh
from IPython.display import clear_output
#@markdown Copy authtoken from https://dashboard.ngrok.com/auth
ngrokToken = "2OOm2DpUhYNlfkZlsoH3nMSpY2d_43KVGcFydXVDhiPyqK78n" #@param  {type: "string"}
ngrokRegion = "in" #@param ["us", "eu", "ap", "au", "sa", "jp", "in"]
launch_ssh(ngrokToken, password, region=ngrokRegion)
clear_output()
print("ssh", user, end='@')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
   "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'][6:].replace(':', ' -p '))"

print("All Setted Up, You can use vps. This script will run on loop to avoid Vps to be closed so soon")
#@markdown Keep In Background
loop = False #@param {type: "boolean"}
while loop:
    time.sleep(1)
